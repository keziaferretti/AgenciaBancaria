# %% [markdown]
# <a href="https://colab.research.google.com/github/keziaferretti/AgenciaBancaria/blob/main/Masterclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'kezia'
# Out:
# 'kezia'

# %%
saudacao = 'Olá Mundo!'

# %%
saudacao
# Out:
# 'Olá Mundo!'

# %%
# Lista
citacao = ['frase 1', 'frase 2'];
citacao
# Out:
# ['frase 1', 'frase 2']

# %%
citacao[0]
# Out:
# 'frase 1'

# %%
#Dicionario

bandas_favoritas = {
    'banda_favorita' : 'Diante do Trono',
    'banda_legalzinha' : 'Band 123'
}
bandas_favoritas
# Out:
# {'banda_favorita': 'Diante do Trono', 'banda_legalzinha': 'Band 123'}

# %%
#Metodos
texto_sujo = "   olá   "
texto_limpo = texto_sujo.strip()
# texto_limpo agora é "olá"
texto_limpo
# Out:
# 'olá'

# %%
def saudar(nome)->str:
  return f'Olá {nome}'

saudar('Kézia')
# Out:
# 'Olá Kézia'
